# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %%
# Data Science Tools and Ecosystem

# %%
Some of the popular languages that Data Scientists use are:

1. Python
2. R
3. SQL
4. Julia
5. Java

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
Some of the commonly used libraries used by Data Scientists include:

1. NumPy
2. Pandas
3. Matplotlib
4. SciPy
5. TensorFlow

# %%
| Data Science Tools         |
|----------------------------|
| Jupyter Notebook           |
| RStudio                    |
| Apache Zeppelin            |

# %%
### Below are a few examples of evaluating arithmetic expressions in Python

- Addition: `5 + 3 = 8`
- Subtraction: `10 - 4 = 6`
- Multiplication: `7 * 6 = 42`
- Division: `12 / 3 = 4`
- Exponentiation: `2 ** 3 = 8`

# %%
# This is a simple arithmetic expression to multiply then add integers
result = (3 * 4) + 5
print(result)  # Expected output is 17

# %%
# This will convert 200 minutes to hours by dividing by 60
hours = 200 / 60
print(hours)  # Expected output: 3.3333 (approximately)
# Out:
# 3.3333333333333335

# %%
**Objectives:**

- List popular languages for Data Science
- Identify commonly used libraries in Data Science
- Explore development environment open-source tools
- Understand arithmetic expressions and their evaluation
- Practice conversion from minutes to hours using Python

# %%
## Author

Abhishek
